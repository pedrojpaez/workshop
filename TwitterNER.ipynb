# %% [markdown]
# # Leveraging Transcribe and Comprehend

# %%
#!pip install twitterscraper

# %% [markdown]
# ## Let's look at the audio files

# %%
# !aws s3 cp s3://dbsbucketpedro/19-198-0002.mp3  .
# Out:
# download: s3://dbsbucketpedro/19-198-0002.mp3 to ./19-198-0002.mp3

# %%
ls
# Out:
# 19-198-0002.mp3                   headline-classifier-mxnet.ipynb
# 19-227-0000.flac                  news.txt
# blazingtext_word2vec_text8.ipynb  output.tar.gz
# car_model_detection.ipynb         tensorflow_bring_your_own_2019-03-12/
# cuisine-classifier.ipynb          test2.json
# custom-mxnet/                     tf-src/
# DeepAR-Electricity.ipynb          Topic+Classifier.ipynb
# headline-classifier.ipynb         TwitterNER.ipynb
# headline-classifier-local.ipynb   xgboost_customer_churn.ipynb

# %%
import IPython
IPython.display.Audio("19-198-0002.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Configure transcribe service and create a transcription job

# %%
import boto3
import time
transcribe = boto3.client('transcribe')

job_name = "test3"
job_uri = "s3://dbsbucketpedro/19-198-0002.mp3"
output_bucket ="dbsbucketpedro"

transcribe.start_transcription_job(
    TranscriptionJobName=job_name,
    Media={'MediaFileUri': job_uri},
    MediaFormat='mp3',
    LanguageCode='en-US',
    OutputBucketName=output_bucket,
    Settings={
        'ShowSpeakerLabels': False,
        'ChannelIdentification': False
    }
)


while True:
    status = transcribe.get_transcription_job(TranscriptionJobName=job_name)
    if status['TranscriptionJob']['TranscriptionJobStatus'] in ['COMPLETED', 'FAILED']:
        break
    print("Not ready yet...")
    time.sleep(5)
print(status)
# Out:
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# {'TranscriptionJob': {'TranscriptionJobName': 'test3', 'TranscriptionJobStatus': 'COMPLETED', 'LanguageCode': 'en-US', 'MediaSampleRateHertz': 44100, 'MediaFormat': 'mp3', 'Media': {'MediaFileUri': 's3://dbsbucketpedro/19-198-0002.mp3'}, 'Transcript': {'TranscriptFileUri': 'https://s3.ap-southeast-1.amazonaws.com/dbsbucketpedro/test3.json'}, 'CreationTime': datetime.datetime(2019, 3, 20, 14, 53, 38, 219000, tzinfo=tzlocal()), 'CompletionTime': datetime.datetime(2019, 3, 20, 14, 54, 39, 730000, tzinfo=tzlocal()), 'Settings': {'ChannelIdentification': False}}, 'ResponseMetadata': {'RequestId': '191a960b-4b20-11e9-8dda-5f01cd37d57f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1', 'date': 'Wed, 20 Mar 2019 14:54:44 GMT', 'x-amzn-requestid': '191a960b-4b20-11e9-8dda-5f01cd37d57f', 'content-length': '436', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %%
response = transcribe.get_transcription_job(
    TranscriptionJobName='test3'
)

# %%
response
# Out:
# {'TranscriptionJob': {'TranscriptionJobName': 'test3',
#   'TranscriptionJobStatus': 'COMPLETED',
#   'LanguageCode': 'en-US',
#   'MediaSampleRateHertz': 44100,
#   'MediaFormat': 'mp3',
#   'Media': {'MediaFileUri': 's3://dbsbucketpedro/19-198-0002.mp3'},
#   'Transcript': {'TranscriptFileUri': 'https://s3.ap-southeast-1.amazonaws.com/dbsbucketpedro/test3.json'},
#   'CreationTime': datetime.datetime(2019, 3, 20, 14, 53, 38, 219000, tzinfo=tzlocal()),
#   'CompletionTime': datetime.datetime(2019, 3, 20, 14, 54, 39, 730000, tzinfo=tzlocal()),
#   'Settings': {'ChannelIdentification': False}},
#  'ResponseMetadata': {'RequestId': '1e3bc13a-4b20-11e9-8a5c-5f889331164c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Wed, 20 Mar 2019 14:54:53 GMT',
#    'x-amzn-requestid': '1e3bc13a-4b20-11e9-8a5c-5f889331164c',
#    'content-length': '436',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Let's look at the results of the transcription

# %%
# !aws s3 cp 's3://dbsbucketpedro/test3.json' .
# Out:
# download: s3://dbsbucketpedro/test3.json to ./test3.json

# %%
import IPython
IPython.display.Audio("19-198-0002.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json
from pprint import pprint

with open('test3.json') as f:
    data = json.load(f)

print(data['results']['transcripts'][0]['transcript'])
# Out:
# Neither the author nor the public have any other concern that, as some observation is necessary upon those parts of the work, which thirteen years have made comparatively obsolete.

# %% [markdown]
# ## Let's analyse the transcription with Comprehend

# %%
import boto3
import json

comprehend = boto3.client(service_name='comprehend', region_name='us-west-2')
#text = "DBS has greatly improved from last year's results"
text=data['results']['transcripts'][0]['transcript']
print('Calling Sentiment Analysis')
print(json.dumps(comprehend.detect_sentiment(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of Sentiment Analysis \n')
# Out:
# Calling Sentiment Analysis
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "162",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Wed, 20 Mar 2019 14:58:14 GMT",
#             "x-amzn-requestid": "961bed65-4b20-11e9-a83a-2d0f83498938"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "961bed65-4b20-11e9-a83a-2d0f83498938",
#         "RetryAttempts": 0
#     },
#     "Sentiment": "NEGATIVE",
#     "SentimentScore": {
#         "Mixed": 0.09399497509002686,
#         "Negative": 0.8744187951087952,
#         "Neutral": 0.02755030058324337,
#         "Positive": 0.00403594970703125
#     }
# }
# End of Sentiment Analysis

# %% [markdown]
# ## Simple example of Comprehend entity extraction

# %%
import boto3
import json

comprehend = boto3.client(service_name='comprehend')
text = "As of January, DBS has outperformed all other major banks in Singapore including HSBC"

print('Calling DetectEntities')
print(json.dumps(comprehend.detect_entities(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectEntities\n')
# Out:
# Calling DetectEntities
# {
#     "Entities": [
#         {
#             "BeginOffset": 0,
#             "EndOffset": 7,
#             "Score": 0.9994915723800659,
#             "Text": "Netflix",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 30,
#             "EndOffset": 33,
#             "Score": 0.5787808895111084,
#             "Text": "DBS",
#             "Type": "ORGANIZATION"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "208",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Wed, 20 Mar 2019 14:06:43 GMT",
#             "x-amzn-requestid": "64b1570f-4b19-11e9-97c1-eb4070bd8c3c"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "64b1570f-4b19-11e9-97c1-eb4070bd8c3c",
#         "RetryAttempts": 0
#     }
# }
# End of DetectEntities

# %% [markdown]
# ## Query twitter messages to run analysis (similar to call center feedbak analysis)

# %%
# !pip install twitterscraper
# Out:
# Collecting twitterscraper
#   Downloading https://files.pythonhosted.org/packages/38/7d/0bf84247b78d7d223914cbf410e1160203a65d39086aaf8c6cad521cec74/twitterscraper-0.9.3.tar.gz
# Collecting coala-utils~=0.5.0 (from twitterscraper)
#   Downloading https://files.pythonhosted.org/packages/54/00/74ec750cfc4e830f9d1cfdd4d559f3d2d4ba1b834b78d5266446db3fd1d6/coala_utils-0.5.1-py3-none-any.whl
# Collecting bs4 (from twitterscraper)
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from twitterscraper) (4.2.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from twitterscraper) (2.20.1)
# Requirement already satisfied: beautifulsoup4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from bs4->twitterscraper) (4.6.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->twitterscraper) (2.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->twitterscraper) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->twitterscraper) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->twitterscraper) (3.0.4)
# Building wheels for collected packages: twitterscraper, bs4
#   Running setup.py bdist_wheel for twitterscraper ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/45/50/9b/70128bca07e2bf8b5ed3f504002e9e74a6eaa5e756341b6931
#   Running setup.py bdist_wheel for bs4 ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built twitterscraper bs4
# fastai 1.0.40 requires dataclasses, which is not installed.
# fastai 1.0.40 requires nvidia-ml-py3, which is not installed.
# thinc 6.12.1 has requirement msgpack<0.6.0,>=0.5.6, but you'll have msgpack 0.6.0 which is incompatible.
# Installing collected packages: coala-utils, bs4, twitterscraper
# Successfully installed bs4-0.0.1 coala-utils-0.5.1 twitterscraper-0.9.3
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from twitterscraper import query_tweets


csv = open('output.txt', "w") 
#"w" indicates that you're writing strings to the file

columnTitleRow = "id, tweet\n"
csv.write(columnTitleRow)
i=0
for tweet in query_tweets("Amazon OR DBS", 10):
    uid = str(i)
    text = tweet.text
    row = uid+','+'"'+tweet.text.replace(',','').replace('\n',' ')+'"' + "\n"
    i=i+1
    csv.write(row)
# Out:
# INFO: queries: ['Amazon OR DBS since:2006-03-21 until:2006-11-13', 'Amazon OR DBS since:2006-11-13 until:2007-07-08', 'Amazon OR DBS since:2007-07-08 until:2008-03-02', 'Amazon OR DBS since:2008-03-02 until:2008-10-25', 'Amazon OR DBS since:2008-10-25 until:2009-06-19', 'Amazon OR DBS since:2009-06-19 until:2010-02-12', 'Amazon OR DBS since:2010-02-12 until:2010-10-07', 'Amazon OR DBS since:2010-10-07 until:2011-06-01', 'Amazon OR DBS since:2011-06-01 until:2012-01-25', 'Amazon OR DBS since:2012-01-25 until:2012-09-18', 'Amazon OR DBS since:2012-09-18 until:2013-05-13', 'Amazon OR DBS since:2013-05-13 until:2014-01-06', 'Amazon OR DBS since:2014-01-06 until:2014-08-31', 'Amazon OR DBS since:2014-08-31 until:2015-04-25', 'Amazon OR DBS since:2015-04-25 until:2015-12-19', 'Amazon OR DBS since:2015-12-19 until:2016-08-12', 'Amazon OR DBS since:2016-08-12 until:2017-04-06', 'Amazon OR DBS since:2017-04-06 until:2017-11-30', 'Amazon OR DBS since:2017-11-30 until:2018-07-25', 'Amazon OR DBS since:2018-07-25 until:2019-03-20']
# INFO: Querying Amazon OR DBS since:2008-10-25 until:2009-06-19
# INFO: Querying Amazon OR DBS since:2009-06-19 until:2010-02-12
# INFO: Querying Amazon OR DBS since:2010-02-12 until:2010-10-07
# INFO: Querying Amazon OR DBS since:2010-10-07 until:2011-06-01
# INFO: Querying Amazon OR DBS since:2011-06-01 until:2012-01-25
# INFO: Querying Amazon OR DBS since:2012-01-25 until:2012-09-18
# INFO: Querying Amazon OR DBS since:2012-09-18 until:2013-05-13
# INFO: Querying Amazon OR DBS since:2013-05-13 until:2014-01-06
# INFO: Querying Amazon OR DBS since:2014-01-06 until:2014-08-31
# INFO: Querying Amazon OR DBS since:2015-04-25 until:2015-12-19
# INFO: Querying Amazon OR DBS since:2014-08-31 until:2015-04-25
# INFO: Querying Amazon OR DBS since:2015-12-19 until:2016-08-12
# INFO: Querying Amazon OR DBS since:2016-08-12 until:2017-04-06
# INFO: Querying Amazon OR DBS since:2006-03-21 until:2006-11-13
# INFO: Querying Amazon OR DBS since:2006-11-13 until:2007-07-08
# INFO: Querying Amazon OR DBS since:2017-11-30 until:2018-07-25
# INFO: Querying Amazon OR DBS since:2017-04-06 until:2017-11-30
# INFO: Querying Amazon OR DBS since:2008-03-02 until:2008-10-25
# INFO: Querying Amazon OR DBS since:2007-07-08 until:2008-03-02
# INFO: Querying Amazon OR DBS since:2018-07-25 until:2019-03-20
# INFO: Got 9 tweets for Amazon%20OR%20DBS%20since%3A2006-03-21%20until%3A2006-11-13.
# INFO: Got 9 tweets (9 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2006-11-13%20until%3A2007-07-08.
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2008-03-02%20until%3A2008-10-25.
# INFO: Got 29 tweets (20 new).
# INFO: Got 49 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2008-10-25%20until%3A2009-06-19.
# INFO: Got 69 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2007-07-08%20until%3A2008-03-02.
# INFO: Got 89 tweets (20 new).
# INFO: Got 19 tweets for Amazon%20OR%20DBS%20since%3A2016-08-12%20until%3A2017-04-06.
# INFO: Got 108 tweets (19 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2009-06-19%20until%3A2010-02-12.
# INFO: Got 128 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2014-01-06%20until%3A2014-08-31.
# INFO: Got 148 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2015-04-25%20until%3A2015-12-19.
# INFO: Got 168 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2013-05-13%20until%3A2014-01-06.
# INFO: Got 188 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2012-01-25%20until%3A2012-09-18.
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2015-12-19%20until%3A2016-08-12.
# INFO: Got 208 tweets (20 new).
# INFO: Got 228 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2017-11-30%20until%3A2018-07-25.
# INFO: Got 248 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2010-02-12%20until%3A2010-10-07.
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2012-09-18%20until%3A2013-05-13.
# INFO: Got 268 tweets (20 new).
# INFO: Got 288 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2018-07-25%20until%3A2019-03-20.
# INFO: Got 308 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2014-08-31%20until%3A2015-04-25.
# INFO: Got 328 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2010-10-07%20until%3A2011-06-01.
# INFO: Got 348 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2011-06-01%20until%3A2012-01-25.
# INFO: Got 368 tweets (20 new).
# INFO: Got 20 tweets for Amazon%20OR%20DBS%20since%3A2017-04-06%20until%3A2017-11-30.
# INFO: Got 388 tweets (20 new).

# %% [markdown]
# ## Output messages to txt

# %%
import pandas as pd
df=pd.read_csv('output.txt')

# %%
df.head()
# Out:
#    id                                              tweet
# 0   0   Amazon Prime you had me at the knock on my door.
# 1   1  Amazon just recommended Paradigms of Artificia...
# 2   2  been online window shopping at amazon all day....
# 3   3  Opening an envelope from Amazon: Maggie Mason'...
# 4   4  Trying to figure out what to buy from Amazon. ...

# %%
df.iloc[:,1].to_csv('tweets.txt')

# %% [markdown]
# ## Run batch Comprehend api calls

# %%
# %%time
import sagemaker
from sagemaker import get_execution_role

role=get_execution_role()
print(role)
sess=sagemaker.Session()
# Out:
# arn:aws:iam::349934754982:role/service-role/AmazonSageMaker-ExecutionRole-20180901T102635
# CPU times: user 445 ms, sys: 43.8 ms, total: 488 ms
# Wall time: 4.01 s

# %%
output_bucket='dbsbucketpedro'
s3 = boto3.resource('s3')
txt = open('tweets.txt', 'rb')
s3.Bucket(output_bucket).put_object(Key='twitterdata/input/tweets.txt', Body=txt)
# Out:
# s3.Object(bucket_name='dbsbucketpedro', key='twitterdata/input/tweets.txt')

# %%
import boto3
import json
comprehend = boto3.client(service_name='comprehend')

# %%
response = comprehend.start_entities_detection_job(
    InputDataConfig={
        'S3Uri': 's3://dbsbucketpedro/twitterdata/input/tweets.txt',
        'InputFormat':'ONE_DOC_PER_LINE'
    },
    OutputDataConfig={
        'S3Uri': 's3://dbsbucketpedro/twitterdata/output/results.txt'
    },
    DataAccessRoleArn=role,
    JobName='tweet-analysis2',
    LanguageCode='en'
)

# %%
# !aws s3 cp s3://dbsbucketpedro/twitterdata/output/results.txt/349934754982-NER-990f64a5e84f2b7546abeae5970bd30a/output/output.tar.gz .
# Out:
# download: s3://dbsbucketpedro/twitterdata/output/results.txt/349934754982-NER-990f64a5e84f2b7546abeae5970bd30a/output/output.tar.gz to ./output.tar.gz

# %%
# !tar -xvf output.tar.gz
# Out:
# output

# %%
# !mv output output.json

# %%
import json
from pprint import pprint

responses=[]
with open('output.json') as f:
    for i in f:
        responses.append(json.loads(i))

# %%
len(df)
# Out:
# 346

# %%
responses[2]['Entities'][1]['Text']
# Out:
# 'amazon'

# %%
len(responses)
# Out:
# 346

# %%
responses[1]['Entities'][1]['Text']
# Out:
# 'Amazon'

# %%
responses[39]
# Out:
# {'Entities': [{'BeginOffset': 0,
#    'EndOffset': 2,
#    'Score': 0.9226970672607422,
#    'Text': '39',
#    'Type': 'QUANTITY'},
#   {'BeginOffset': 60,
#    'EndOffset': 63,
#    'Score': 0.4131833016872406,
#    'Text': 'one',
#    'Type': 'QUANTITY'}],
#  'File': 'tweets.txt',
#  'Line': 39}

# %%
df['Org']='Na'
df['Score']='Na'
for i in range(len(df)):
    try:
        df['Org'][i]=responses[i]['Entities'][1]['Text']
        df['Score'][i]=responses[i]['Entities'][1]['Score']
    except Exception:
        pass
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head(30)
# Out:
#     id                                              tweet  \
# 0    0   Amazon Prime you had me at the knock on my door.
# 1    1  Amazon just recommended Paradigms of Artificia...
# 2    2  been online window shopping at amazon all day....
# 3    3  Opening an envelope from Amazon: Maggie Mason'...
# 4    4  Trying to figure out what to buy from Amazon. ...
# 5    5  trying to order the new" R.E.M. CD from amazon...
# 6    6  just got free Amazon Prime 2-day shipping for ...
# 7    7  telene's icon is quite the amazon. goodnight i...
# 8    8                     amazon strippers at 3 o'clock.
# 9    9  Lost all my album art during the last iTunes i...
# 10  10  Lots of cool things going on with the Amazon S...
# 11  11  Browsing thru LifeHacker Amazon Wikipedia Goog...
# 12  12  No to do the same on the amazon server (produc...
# 13  13  Finishing up the decorations and listening to ...
# 14  14  ユリイカの任天堂特集見てたら、マリオ64やりたくなってクラシックコントローラをAmazonで注文。
# 15  15                                    browsing Amazon
# 16  16   開始將我用 Rails 寫既 workflow engine port 去 Amazon EC2
# 17  17                         用 amazon 起左個 EC2 instant 了
# 18  18  New blog post: Amazon taking pre-orders for Ma...
# 19  19                   amazonに注文したRailsの本がなかなか届かない(>_<)
# 20  20  My video camera is due to deliver today from A...
# 21  21    詳解UNIXプログラミングをAmazonで注文。べっ、別に現実逃避なんかじゃないんだからねっ。
# 22  22  trying to figure out how to unsubscribe from a...
# 23  23  I have gone Twisted Python and Amazon EC2/S3 c...
# 24  24               Amazonのお急ぎ便、配達が明日になりそうっぽい、、、待ってたのに！！
# 25  25  Bookmarking: Going My Way: Amazon の書籍のページと Goo...
# 26  26                         でかけたいけど、まだAmazonお急ぎ便届かないや。
# 27  27  エントリー書いた: Going My Way: Amazon の書籍のページと Google...
# 28  28                        Amazonの強みのひとつは万引きされないということか
# 29  29  Flavorless cakes These popcorn cakes are my ab...
#
#                                     Org     Score
# 0                                Amazon  0.996473
# 1                                Amazon  0.998203
# 2                                amazon  0.995901
# 3                                Amazon  0.993774
# 4                                Amazon  0.998071
# 5                             R.E.M. CD  0.641165
# 6                                Amazon  0.993983
# 7                                amazon  0.957353
# 8                                amazon   0.98877
# 9                                iTunes  0.912235
# 10                               Amazon  0.933901
# 11                               Amazon  0.992834
# 12                               amazon  0.981741
# 13                               Amazon  0.988175
# 14                                   64  0.670249
# 15                               Amazon  0.994144
# 16                               Amazon  0.998167
# 17                               amazon  0.975527
# 18                               Amazon  0.995445
# 19                                   Na        Na
# 20                                today  0.967027
# 21                                   Na        Na
# 22                               amazon  0.954911
# 23                       Twisted Python  0.899955
# 24                                   Na        Na
# 25                               Amazon  0.991294
# 26                                   Na        Na
# 27                               Amazon  0.989035
# 28                                   Na        Na
# 29  http://www.amazon.com/dp/B000HD0PJQ  0.999927
